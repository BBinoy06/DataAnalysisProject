# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

df = pd.read_csv("Mobile_Price_Classification.csv")
df.columns = df.columns.str.lower().str.replace(" ", "_")
print(df.head())
# Out:
#      model    brand  os_version  screen_size_inches  battery_mah  ram_gb  \
# 0  SAM-589  Samsung  Android 12                5.16         3800      12
# 1  VIV-521     Vivo  Android 11                5.53         3400      12
# 2  XIA-595   Xiaomi  Android 10                6.74         5200       8
# 3  TEC-160    Tecno      iOS 14                5.73         3100       4
# 4  APP-735    Apple  Android 12                5.22         3600       2
#
#    storage_gb  rear_camera_mp  front_camera_mp   processor  ...  \
# 0         512              96               40      Exynos  ...
# 1          32              48               40  Snapdragon  ...
# 2          64              24               10    MediaTek  ...
# 3         128              20               30    MediaTek  ...
# 4         128              92               15  Snapdragon  ...
#
#    fingerprint_sensor dual_sim     warranty screen_type charging_port  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model               500 non-null    object
#  1   brand               500 non-null    object
#  2   os_version          500 non-null    object
#  3   screen_size_inches  500 non-null    float64
#  4   battery_mah         500 non-null    int64
#  5   ram_gb              500 non-null    int64
#  6   storage_gb          500 non-null    int64
#  7   rear_camera_mp      500 non-null    int64
#  8   front_camera_mp     500 non-null    int64
#  9   processor           500 non-null    object
#  10  refresh_rate_hz     500 non-null    int64
#  11  connectivity        500 non-null    object
#  12  face_unlock         500 non-null    object
#  13  fingerprint_sensor  500 non-null    object
#  14  dual_sim            500 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# model                 0
# brand                 0
# os_version            0
# screen_size_inches    0
# battery_mah           0
# ram_gb                0
# storage_gb            0
# rear_camera_mp        0
# front_camera_mp       0
# processor             0
# refresh_rate_hz       0
# connectivity          0
# face_unlock           0
# fingerprint_sensor    0
# dual_sim              0
# warranty              0
# screen_type           0
# charging_port         0
# fast_charging         0
# body_material         0
# weight_g              0
# thickness_mm          0
# price_category        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
if 'os_version' in df.columns:
    df['os_name'] = df['os_version'].str.split().str[0]
    df['os_version_number'] = df['os_version'].str.split().str[1].astype(int)
    df.drop(columns=['os_version'], inplace=True)

print(df[['os_name', 'os_version_number']].head())
# Out:
#    os_name  os_version_number
# 0  Android                 12
# 1  Android                 11
# 2  Android                 10
# 3      iOS                 14
# 4  Android                 12

# %%
df.select_dtypes(include='object').nunique()
# Out:
# model                 484
# brand                   9
# processor               5
# connectivity            2
# face_unlock             2
# fingerprint_sensor      2
# dual_sim                2
# warranty                3
# screen_type             4
# charging_port           3
# fast_charging           2
# body_material           3
# price_category          4
# os_name                 2
# dtype: int64

# %%
df.drop(columns=['model'], inplace=True)
